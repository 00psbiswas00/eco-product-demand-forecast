# %%
import pandas as pd
import sqlite3

# %%
con= sqlite3.connect('../data/raw/trends.db')
df=pd.read_sql(f'SELECT * FROM trends_raw', con)
df.head(5)
# Out:
#                   date  sustainable fashion  eco-friendly clothing  \
# 0  2024-08-11 00:00:00                  9.0                    0.0
# 1  2024-08-18 00:00:00                 11.0                    0.0
# 2  2024-08-25 00:00:00                 11.0                    0.0
# 3  2024-09-01 00:00:00                 10.0                    1.0
# 4  2024-09-08 00:00:00                 11.0                    0.0
#
#    organic cotton  eco-friendly products  biodegradable packaging  isPartial  \
# 0            48.0                    2.0                      3.0          0
# 1            53.0                    2.0                      3.0          0
# 2            48.0                    2.0                      4.0          0
# 3            51.0                    2.0                      3.0          0
# 4            51.0                    3.0                      3.0          0
#
#    zero waste products  green energy  solar panels  electric scooter  \
# ...
