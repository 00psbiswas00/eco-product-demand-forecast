# %%
""" import sys
sys.path.append('../scripts') """
# Out:
# " import sys\nsys.path.append('../scripts') "

# %%
import pandas as pd
import sqlite3

# %%
con= sqlite3.connect(database='../data/raw/trends.db')

# %%
df= pd.read_sql('SELECT * FROM trends_raw', con)

# %%
con.close()

# %%
df.head()
# Out:
#                   date  100% vegan   bio  biodegradable  compostable  \
# 0  2024-08-11 00:00:00         0.0  91.0            2.0          1.0
# 1  2024-08-18 00:00:00         0.0  94.0            2.0          1.0
# 2  2024-08-25 00:00:00         0.0  91.0            2.0          1.0
# 3  2024-09-01 00:00:00         0.0  91.0            2.0          1.0
# 4  2024-09-08 00:00:00         0.0  94.0            2.0          1.0
#
#    ecological  isPartial  ethical trade  fair trade  fairtrade  ...  \
# 0         2.0          0            NaN         NaN        NaN  ...
# 1         3.0          0            NaN         NaN        NaN  ...
# 2         4.0          0            NaN         NaN        NaN  ...
# 3         4.0          0            NaN         NaN        NaN  ...
# 4         5.0          0            NaN         NaN        NaN  ...
#
#    plant-based  plastic free  plastic-free  recyclable  recycled  refillable  \
# 0          NaN           NaN           NaN         NaN       NaN         NaN
# 1          NaN           NaN           NaN         NaN       NaN         NaN
# 2          NaN           NaN           NaN         NaN       NaN         NaN
# 3          NaN           NaN           NaN         NaN       NaN         NaN
# 4          NaN           NaN           NaN         NaN       NaN         NaN
#
#    reusable  vegan  vegan friendly  washable
# 0       NaN    NaN             NaN       NaN
# 1       NaN    NaN             NaN       NaN
# 2       NaN    NaN             NaN       NaN
# 3       NaN    NaN             NaN       NaN
# 4       NaN    NaN             NaN       NaN
#
# [5 rows x 23 columns]

# %%
df.describe()
# Out:
#        100% vegan         bio  biodegradable  compostable  ecological  \
# count        53.0   53.000000      53.000000         53.0   53.000000
# mean          0.0   94.660377       2.320755          1.0    3.943396
# std           0.0    3.168010       0.510414          0.0    0.864138
# min           0.0   86.000000       2.000000          1.0    2.000000
# 25%           0.0   93.000000       2.000000          1.0    3.000000
# 50%           0.0   95.000000       2.000000          1.0    4.000000
# 75%           0.0   98.000000       3.000000          1.0    5.000000
# max           0.0  100.000000       4.000000          1.0    5.000000
#
#         isPartial  ethical trade  fair trade  fairtrade  made from recycled  \
# count  265.000000      53.000000   53.000000  53.000000           53.000000
# mean     0.018868       1.924528   36.622642  12.037736            3.320755
# std      0.136316       0.474303   12.078631   2.303528            0.580901
# min      0.000000       1.000000   27.000000   7.000000            2.000000
# 25%      0.000000       2.000000   31.000000  10.000000            3.000000
# 50%      0.000000       2.000000   34.000000  12.000000            3.000000
# 75%      0.000000       2.000000   36.000000  14.000000            4.000000
# max      1.000000       3.000000  100.000000  16.000000            4.000000
#
#        ...  plant-based  plastic free  plastic-free  recyclable   recycled  \
# count  ...    53.000000     53.000000          53.0   53.000000  53.000000
# mean   ...     1.113208      1.773585           0.0    2.943396   7.830189
# std    ...     0.466591      0.697289           0.0    0.233295   0.802301
# min    ...     1.000000      1.000000           0.0    2.000000   6.000000
# 25%    ...     1.000000      1.000000           0.0    3.000000   7.000000
# 50%    ...     1.000000      2.000000           0.0    3.000000   8.000000
# 75%    ...     1.000000      2.000000           0.0    3.000000   8.000000
# max    ...     4.000000      4.000000           0.0    3.000000  11.000000
#
#        refillable   reusable       vegan  vegan friendly    washable
# count   53.000000  53.000000   53.000000       53.000000   53.000000
# mean     2.396226   8.830189   79.716981        0.773585   68.509434
# std      0.531313   0.955467    5.838787        0.422516    7.999093
# min      2.000000   8.000000   70.000000        0.000000   58.000000
# 25%      2.000000   8.000000   76.000000        1.000000   64.000000
# 50%      2.000000   9.000000   78.000000        1.000000   67.000000
# 75%      3.000000   9.000000   83.000000        1.000000   71.000000
# max      4.000000  13.000000  100.000000        1.000000  100.000000
#
# [8 rows x 22 columns]

# %%
df.isna().sum()
# Out:
# date                    0
# 100% vegan            212
# bio                   212
# biodegradable         212
# compostable           212
# ecological            212
# isPartial               0
# ethical trade         212
# fair trade            212
# fairtrade             212
# made from recycled    212
# no plastic            212
# organic               212
# plant-based           212
# plastic free          212
# plastic-free          212
# recyclable            212
# recycled              212
# refillable            212
# reusable              212
# vegan                 212
# vegan friendly        212
# washable              212
# dtype: int64

# %%
df=df.reset_index()

# %%
df= df.melt(id_vars=['date'], var_name='Keyword', value_name='Value')

# %%
df['date'] = df['date'].dt.strftime("%Y-%m-%d")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 df['date'] = df['date'].dt.strftime("%Y-%m-%d")
#
# File ~/Desktop/portfolio/eco-product-demand-forecast/.venv/lib/python3.12/site-packages/pandas/core/generic.py:6318, in NDFrame.__getattr__(self, name)
#    6311 if (
#    6312     name not in self._internal_names_set
#    6313     and name not in self._metadata
#    6314     and name not in self._accessors
#    6315     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6316 ):
#    6317     return self[name]
# -> 6318 return object.__getattribute__(self, name)
#
# File ~/Desktop/portfolio/eco-product-demand-forecast/.venv/lib/python3.12/site-packages/pandas/core/accessor.py:224, in CachedAccessor.__get__(self, obj, cls)
#     221 if obj is None:
#     222     # we're accessing the attribute of the class, i.e., Dataset.geo
#     223     return self._accessor
# --> 224 accessor_obj = self._accessor(obj)
#     225 # Replace the property with the accessor object. Inspired by:
#     226 # https://www.pydanny.com/cached-property.html
#     227 # We need to use object.__setattr__ because we overwrite __setattr__ on
#     228 # NDFrame
#     229 object.__setattr__(obj, self._name, accessor_obj)
#
# File ~/Desktop/portfolio/eco-product-demand-forecast/.venv/lib/python3.12/site-packages/pandas/core/indexes/accessors.py:643, in CombinedDatetimelikeProperties.__new__(cls, data)
#     640 elif isinstance(data.dtype, PeriodDtype):
#     641     return PeriodProperties(data, orig)
# --> 643 raise AttributeError("Can only use .dt accessor with datetimelike values")
#
# AttributeError: Can only use .dt accessor with datetimelike values

# %%
df= df.drop_duplicates(subset=['date', 'Keyword'])

# %%
df['Value']= df['Value'].fillna(0).astype(int)
# Out:
# /var/folders/dn/6hvnc_t17yg34gpgwcw9ypg00000gn/T/ipykernel_19475/905017008.py:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Value']= df['Value'].fillna(0).astype(int)

# %%
df=df.sort_values(['Keyword', 'date'])

# %%
import sqlite3
import pandas as pd

# %%
conn = sqlite3.connect("../data/processed/trends.db")

# %%
data= pd.read_sql('SELECT * FROM trends_processed;', conn)
data.head()
# Out:
#          date     keyword  value
# 0  2024-08-11  100% vegan      0
# 1  2024-08-18  100% vegan      0
# 2  2024-08-25  100% vegan      0
# 3  2024-09-01  100% vegan      0
# 4  2024-09-08  100% vegan      0

# %%
data['keyword'].values
# Out:
# array(['100% vegan', '100% vegan', '100% vegan', ..., 'washable',
#        'washable', 'washable'], shape=(1113,), dtype=object)

# %%
data.tail()
# Out:
#             date   keyword  value
# 1108  2025-07-13  washable     73
# 1109  2025-07-20  washable     78
# 1110  2025-07-27  washable     80
# 1111  2025-08-03  washable     99
# 1112  2025-08-10  washable    100

# %%
data[data['value']!=0].head()
# Out:
#           date keyword  value
# 53  2024-08-11     bio     85
# 54  2024-08-18     bio     88
# 55  2024-08-25     bio     84
# 56  2024-09-01     bio     86
# 57  2024-09-08     bio     88
